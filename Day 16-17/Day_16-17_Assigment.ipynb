# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-6fab06cda22c> in <module>()
#       1 from IPython.core.display import HTML
# ----> 2 css = open('style-table.css').read() + open('style-notebook.css').read()
#       3 HTML('<style>{}</style>'.format(css))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'style-table.css'

# %%
titles = pd.read_csv('data/titles.csv')
titles.head()
# Out:
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970
# 3               Machine  2007
# 4                  MARy  2008

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
titles.size
# Out:
# 489828

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
earliestFilm = titles.sort_values('year')
earliestFilm.head(2)
# Out:
#                      title  year
# 193222          Miss Jerry  1894
# 51388   The Startled Lover  1898

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
#hamlet = titles['title'].where(titles['title']  'Hamlet')

len(titles[titles['title']=='Hamlet'])
# Out:
# 20

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
len(titles[titles['title']=='North by Northwest'])
# Out:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
titles[titles['title'] == 'Hamlet'].sort_values('year').head(1)
# Out:
#         title  year
# 52521  Hamlet  1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles['title'] == 'Treasure Island'].sort_values('year')
# Out:
#                   title  year
# 55686   Treasure Island  1918
# 196514  Treasure Island  1920
# 141822  Treasure Island  1934
# 77354   Treasure Island  1950
# 65051   Treasure Island  1972
# 37238   Treasure Island  1973
# 173051  Treasure Island  1985
# 27076   Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
len(titles[titles['year'] == 1950])
# Out:
# 1113

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
len(titles[titles['year'] == 1960])
# Out:
# 1549

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
x = (titles[(titles['year'] > 1950) & (titles['year'] < 1959)])

len(x)
# Out:
# 10306

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles[titles.title=='Batman']
# Out:
#           title  year                   name     type  \
# 99564    Batman  1943           Frank Austin    actor
# 100080   Batman  1943         William Austin    actor
# 118792   Batman  1989              Del Baker    actor
# 124426   Batman  1989        Michael Balfour    actor
# 155945   Batman  1989             David Baxt    actor
# 207270   Batman  1989          Paul Birchard    actor
# 219969   Batman  1989             Hugo Blick    actor
# 268990   Batman  1943           Lynton Brent    actor
# 298576   Batman  1943              Roy Bucko    actor
# 394031   Batman  1989             Carl Chase    actor
# 402760   Batman  1943        George Chesebro    actor
# 464883   Batman  1989         Kenneth Coombs    actor
# 466461   Batman  1989     George Lane Cooper    actor
# 486381   Batman  1989           Harold Coyne    actor
# 487589   Batman  1989            Edwin Craig    actor
# 495187   Batman  1943          Douglas Croft    actor
# ...

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast_titles = pd.read_csv('data/cast.csv')
cast_titles.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
x=cast_titles[cast_titles['title']=='Inception']
print('List of all role in movie Inception:',x)
print('Count of all the roles in movie Inception: ',len(x))
# Out:
#              title  year                     name     type  \
# 98153    Inception  2010     Michael (III) August    actor
# 149008   Inception  2010             Peter Basham    actor
# 183937   Inception  2010             Tom Berenger    actor
# 197877   Inception  2010                 Ken Bhan    actor
# 260128   Inception  2010           Virgile Bramly    actor
# 326745   Inception  2010            Michael Caine    actor
# 333415   Inception  2010             Earl Cameron    actor
# 374661   Inception  2010            John Ceallach    actor
# 433867   Inception  2010            Nicolas Clerc    actor
# 444385   Inception  2010           Adam (IV) Cole    actor
# 497161   Inception  2010             Garvin Cross    actor
# 517227   Inception  2010       Jean-Michel Dagory    actor
# 590576   Inception  2010        Leonardo DiCaprio    actor
# 684098   Inception  2010            Seve Esposito    actor
# 690634   Inception  2010      Marcus (II) Everett    actor
# ...

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
x=cast_titles[(cast_titles['title']=='Inception')]
#print(x['n'])
y = x['n'].isnull().sum()
print('Roles which is missing rank is:',y)
# Out:
# Roles which is missing rank is: 27

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
allInceptiondf=cast_titles[(cast_titles['title']=='Inception')]
rolesRecRank=allInceptiondf['n'].notnull().sum()
print('Roles which recieved ranks are :',rolesRecRank)
# Out:
# Roles which recieved ranks are : 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
allInceptiondf=cast_titles[(cast_titles['title']=='North by Northwest')]
allInceptiondf[allInceptiondf['n'].notna()].sort_values('n')
# Out:
#                       title  year                  name     type  \
# 871426   North by Northwest  1959            Cary Grant    actor
# 3518333  North by Northwest  1959       Eva Marie Saint  actress
# 1457165  North by Northwest  1959           James Mason    actor
# 3157232  North by Northwest  1959   Jessie Royce Landis  actress
# 356707   North by Northwest  1959        Leo G. Carroll    actor
# 3048272  North by Northwest  1959  Josephine Hutchinson  actress
# 1695173  North by Northwest  1959           Philip Ober    actor
# 1275337  North by Northwest  1959         Martin Landau    actor
# 2447081  North by Northwest  1959         Adam Williams    actor
# 1811387  North by Northwest  1959          Edward Platt    actor
# 665768   North by Northwest  1959     Robert Ellenstein    actor
# 2295714  North by Northwest  1959          Les Tremayne    actor
# 464736   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
allInceptiondf=cast_titles[(cast_titles['title']=='Sleuth')& (cast_titles['year']==1972)].sort_values('n')
allInceptiondf
# Out:
#           title  year                name     type  \
# 1705394  Sleuth  1972    Laurence Olivier    actor
# 326773   Sleuth  1972       Michael Caine    actor
# 373876   Sleuth  1972      Alec Cawthorne    actor
# 1465483  Sleuth  1972  John (II) Matthews    actor
# 2724553  Sleuth  1972  Eve (III) Channing  actress
# 1448690  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1705394                 Andrew Wyke  1.0
# 326773                  Milo Tindle  2.0
# 373876            Inspector Doppler  3.0
# 1465483  Detective Sergeant Tarrant  4.0
# 2724553             Marguerite Wyke  5.0
# 1448690      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
allSleuthdf=cast_titles[(cast_titles['title']=='Sleuth')& (cast_titles['year']==2007)]
print('Cast without Nan: \n',allSleuthdf[allSleuthdf['n'].notna()].sort_values('n'))
print('-----------------------------------------------------------------------------')
print('Cast with Nan: \n',allSleuthdf.sort_values('n'))
# Out:
# Cast without Nan:
#            title  year           name   type    character    n
# 326774   Sleuth  2007  Michael Caine  actor       Andrew  1.0
# 1293634  Sleuth  2007       Jude Law  actor         Milo  2.0
# 1805907  Sleuth  2007  Harold Pinter  actor  Man on T.V.  3.0
# -----------------------------------------------------------------------------
# Cast with Nan:
#            title  year                 name     type          character    n
# 326774   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1293634  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1805907  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 260242   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 373877   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2724552  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3370424  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
allHamletdf=cast_titles[(cast_titles.title == 'Hamlet') & (cast_titles.year == 1921)]
len(allHamletdf.character)
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
allHamletdf=cast_titles[ (cast_titles['title']=='Hamlet') & (cast_titles.year == 1996) &(cast_titles.name.str.contains('Branagh'))]
allHamletdf
# Out:
#          title  year             name   type character    n
# 260225  Hamlet  1996  Kenneth Branagh  actor    Hamlet  5.0

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
allHamletdf=cast_titles[(cast_titles.character == 'Hamlet')]
len(allHamletdf)
# Out:
# 96

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
allOpheliadf=cast_titles[(cast_titles['character']=='Ophelia')]
len(allOpheliadf)
# Out:
# 117

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
allOpheliadf=cast_titles[(cast_titles['character']=='The Dude')]
allOpheliadf
# Out:
#                                   title  year                  name   type  \
# 272161                 The Big Lebowski  1998          Jeff Bridges  actor
# 339389               Terms & Conditions  2015           Jordan Cann  actor
# 498660                         Stranger  2000         Scott Crowell  actor
# 570128           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 610791                      Sweepstakes  1931           Mike Donlin  actor
# 629473                    Self Helpless  2010        Devin The Dude  actor
# 855976                A Few Brains More  2012    Michael D. Goodwin  actor
# 1089444  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1138933                   Explicit Ills  2008    Christopher Kadish  actor
# 1367230                 American Idiots  2013      Jason Loughridge  actor
# 1386561             The Winds of Autumn  1976           Steve Lyons  actor
# ...

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
allOpheliadf=cast_titles[(cast_titles['character']=='The Stranger')]
allOpheliadf
# Out:
#                                               title  year  \
# 25954                                         Theeb  2014
# 35748                                My Time to Die  2014
# 46418                                        Hickok  2017
# 67421                                      Get Mean  1975
# 67424                      Lo straniero di silenzio  1968
# 67426                        Un dollaro tra i denti  1967
# 67427              Un uomo, un cavallo, una pistola  1967
# 83015                   Buzzy and the Phantom Pinto  1941
# 122115               And Here No Devil Can Hurt You  2011
# 124180                                   Hungry Man  2013
# 140214                               Trading Hearts  1988
# 142205                             The Gospel of Us  2012
# 148595                                      Winning  1969
# 200505                                Urban Odyssey  2010
# 209282                               Suit of Lights  2014
# ...

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
allOpheliadf=cast_titles[(cast_titles['name']=='Sidney Poitier')]
len(allOpheliadf)
# Out:
# 43

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
allOpheliadf=cast_titles[(cast_titles['name']=='Judi Dench')]
#allOpheliadf
len(allOpheliadf)
# Out:
# 55

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
#allOpheliadf=cast_titles[(cast_titles['name']=='Cary Grant') & (cast_titles['year']==1940) & (cast_titles['n']==2)]
allOpheliadf=cast_titles[(cast_titles['name']=='Cary Grant')& (cast_titles['n']==2)& (cast_titles['year']>= 1940) & (cast_titles['year']<= 1950) ]
allOpheliadf
# Out:
#                    title  year        name   type    character    n
# 871423  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 871433    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
allOpheliadf=cast_titles[(cast_titles['name']=='Cary Grant')& (cast_titles['n']==1)
                         &(cast_titles['year']>= 1940) & (cast_titles['year']< 1950) ]
allOpheliadf.sort_values('year')
# Out:
#                                        title  year        name   type  \
# 871448               The Howards of Virginia  1940  Cary Grant  actor
# 871407                       His Girl Friday  1940  Cary Grant  actor
# 871450                The Philadelphia Story  1940  Cary Grant  actor
# 871438                             Suspicion  1941  Cary Grant  actor
# 871452                  The Talk of the Town  1942  Cary Grant  actor
# 871429                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 871398                     Destination Tokyo  1943  Cary Grant  actor
# 871422                             Mr. Lucky  1943  Cary Grant  actor
# 871430                      Once Upon a Time  1944  Cary Grant  actor
# 871390                  Arsenic and Old Lace  1944  Cary Grant  actor
# 871425             None But the Lonely Heart  1944  Cary Grant  actor
# 871424                         Night and Day  1946  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
allOpheliadf=cast_titles[(cast_titles['year']>= 1950) & (cast_titles['year']< 1960) & (cast_titles['type'] == 'actor') ]
allOpheliadf.sort_values('year')
# Out:
#                                    title  year                 name   type  \
# 1561725                   Yuki fujin ezu  1950         Shir? Mizuki  actor
# 2310638                      The Capture  1950        Felipe Turich  actor
# 2310628                      Short Grass  1950        Felipe Turich  actor
# 201278                       Riding High  1950     Charles Bickford  actor
# 1035207                           Ambush  1950           Reed Howes  actor
# 2171730                    The Blue Lamp  1950  Anthony (III) Steel  actor
# 782085              Min kone er uskyldig  1950             Ib F?rst  actor
# 201315                         Whirlpool  1950     Charles Bickford  actor
# 1946863                       El portero  1950   Humberto Rodr?guez  actor
# 1408452         My Friend Irma Goes West  1950         Mike Mahoney  actor
# 1946866                El rey del barrio  1950   Humberto Rodr?guez  actor
# ...

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
allOpheliadf=cast_titles[(cast_titles['type']=='actress')
                         &(cast_titles['year']>= 1950) & (cast_titles['year']< 1960) ]
allOpheliadf.sort_values('year')
# Out:
#                                    title  year  \
# 2532684           A Woman of Distinction  1950
# 2981164              Dos gallos de pelea  1950
# 2981177                     El desalmado  1950
# 2981251                    La fe en Dios  1950
# 2981259            La marca del zorrillo  1950
# 2981278              Las dos huerfanitas  1950
# 2981280                      Lluvia roja  1950
# 2981332                   Sobre las olas  1950
# 2981157                Cuide a su marido  1950
# 2981454                        Marihuana  1950
# 2981679   Der Schatten des Herrn Monitor  1950
# 2981681                  Export in Blond  1950
# 2981682                     Hafenmelodie  1950
# 2981861            Das doppelte Lottchen  1950
# 2981871            Das doppelte Lottchen  1950
# 2982035                     Zhujiang lei  1950
# 2982244               Absender unbekannt  1950
# 2981611                  Regementets ros  1950
# 2982286                          Furioso  1950
# ...

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
allOpheliadf=cast_titles[(cast_titles['n']==1)
                          & (cast_titles['year']< 1980) ]
allOpheliadf.sort_values('year')
# Out:
#                                          title  year                    name  \
# 3634679            The Story of the Kelly Gang  1906          Elizabeth Tait
# 1272777                          Lika mot lika  1906            Knut Lambert
# 794541      The Joe Gans-Battling Nelson Fight  1906                Joe Gans
# 818490                      Robbery Under Arms  1907              Jim Gerald
# 154605          The Fairylogue and Radio-Plays  1908           L. Frank Baum
# 952438                       The Life of Moses  1909            Pat Hartigan
# 3183324                   Lucrezia Borgia (II)  1910        Vittoria Lepanto
# 2860093                              Jane Eyre  1910             Marie Eline
# 2841510                La petite Blanche-Neige  1910        H?l?ne Du Montel
# 3749619                The Squatter's Daughter  1910            Olive Wilton
# 2371817                          Pyotr Velikiy  1910            Pyotr Voinov
# ...

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
allOpheliadf=cast_titles[(cast_titles['n']>1)
                          & (cast_titles['year']< 1980) ]
allOpheliadf.sort_values('year')
# Out:
#                                       title  year                    name  \
# 3154953                       Lika mot lika  1906         Helfrid Lambert
# 2228011         The Story of the Kelly Gang  1906               John Tait
# 1646281  The Joe Gans-Battling Nelson Fight  1906         Battling Nelson
# 3778962                       Lika mot lika  1906          Tollie Zellman
# 1526242                  Robbery Under Arms  1907         George Merriman
# 2339659                  Robbery Under Arms  1907              Lance Vane
# 630362                   Robbery Under Arms  1907            William Duff
# 896711                   Robbery Under Arms  1907            Arthur Guest
# 969873       The Fairylogue and Radio-Plays  1908      Daniel (III) Heath
# 2041742      The Fairylogue and Radio-Plays  1908          Joseph Schrode
# 2657073      The Fairylogue and Radio-Plays  1908           Mrs. Bostwick
# 2459429      The Fairylogue and Radio-Plays  1908        George E. Wilson
# ...

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
total_num=cast_titles['character'][((cast_titles.n!=1 ) | (cast_titles.n!=2)) & (cast_titles.year<=1980)]
print(len(total_num))
# Out:
# 1182807
